# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')
data=train_data
data
# Out:
#            ID Customer_ID     Month           Name   Age          SSN  \
# 0      0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265
# 1      0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265
# 2      0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265
# 3      0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265
# 4      0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265
# ...       ...         ...       ...            ...   ...          ...
# 30390  0xc810  CUS_0x90cf      July        McCoolw   53_  058-50-1241
# 30391  0xc811  CUS_0x90cf    August        McCoolw    53  058-50-1241
# 30392  0xc816  CUS_0x686c   January            NaN    36  666-90-8248
# 30393  0xc817  CUS_0x686c  February        Kiharap    36  666-90-8248
# 30394  0xc818  CUS_0x686c     March        Kiharap    36    #F%$D@*&8
#
#           Occupation       Annual_Income  Monthly_Inhand_Salary  \
# 0          Scientist            19114.12            1824.843333
# 1          Scientist            19114.12                    NaN
# 2          Scientist            19114.12                    NaN
# 3          Scientist            19114.12                    NaN
# 4          Scientist            19114.12            1824.843333
# ...              ...                 ...                    ...
# 30390  Media_Manager  106234.11000000002            8699.842500
# 30391  Media_Manager  106234.11000000002            8699.842500
# 30392      Developer            10143.89             684.324167
# 30393      Developer            10143.89             684.324167
# 30394      Developer            10143.89             684.324167
#
#        Num_Bank_Accounts  ...  Credit_Mix  Outstanding_Debt  \
# 0                      3  ...           _            809.98
# 1                      3  ...        Good            809.98
# 2                      3  ...        Good            809.98
# 3                      3  ...        Good            809.98
# 4                      3  ...        Good            809.98
# ...                  ...  ...         ...               ...
# 30390                  4  ...    Standard             939.4
# 30391                  4  ...    Standard             939.4
# 30392                  4  ...    Standard           1083.92
# 30393                  4  ...    Standard           1083.92
# 30394                  4  ...         NaN               NaN
#
#       Credit_Utilization_Ratio      Credit_History_Age  Payment_of_Min_Amount  \
# 0                    26.822620   22 Years and 1 Months                     No
# 1                    31.944960                     NaN                     No
# 2                    28.609352   22 Years and 3 Months                     No
# 3                    31.377862   22 Years and 4 Months                     No
# 4                    24.797347   22 Years and 5 Months                     No
# ...                        ...                     ...                    ...
# 30390                23.595624   27 Years and 3 Months                     No
# 30391                36.009422                     NaN                     No
# 30392                23.002059  19 Years and 10 Months                    Yes
# 30393                25.142233                     NaN                    Yes
# 30394                      NaN                     NaN                    NaN
#
#       Total_EMI_per_month Amount_invested_monthly  \
# 0               49.574949       80.41529543900253
# 1               49.574949      118.28022162236736
# 2               49.574949         81.699521264648
# 3               49.574949       199.4580743910713
# 4               49.574949      41.420153086217326
# ...                   ...                     ...
# 30390          201.113490       325.6671223639741
# 30391          201.113490       625.8471560943485
# 30392           22.886533       50.41183191530408
# 30393           22.886533       46.36582910605607
# 30394                 NaN                     NaN
#
#                       Payment_Behaviour     Monthly_Balance Credit_Score
# 0       High_spent_Small_value_payments  312.49408867943663         Good
# 1        Low_spent_Large_value_payments  284.62916249607184         Good
# 2       Low_spent_Medium_value_payments   331.2098628537912         Good
# 3        Low_spent_Small_value_payments  223.45130972736786         Good
# 4      High_spent_Medium_value_payments  341.48923103222177         Good
# ...                                 ...                 ...          ...
# 30390  High_spent_Medium_value_payments   593.2036374964807     Standard
# 30391    Low_spent_Large_value_payments  313.02360376610636     Standard
# 30392    Low_spent_Small_value_payments    285.134051935071     Standard
# 30393    Low_spent_Small_value_payments    289.180054744319     Standard
# 30394                               NaN                 NaN          NaN
#
# [30395 rows x 28 columns]
# Warning: Total number of columns (28) exceeds max_columns (20) limiting to first (20) columns.
# Warning: total number of rows (30395) exceeds max_rows (20000). Limiting to first (20000) rows.
# Warning: Total number of columns (28) exceeds max_columns (20) limiting to first (20) columns.
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
 data.dropna(inplace=True)

# %%
# Define features and target variable
X = data.drop('Credit_Score', axis=1)
y = data['Credit_Score']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Define features and target variable
X = data.drop('Credit_Score', axis=1)

# Convert columns with 'object' dtype to numerical using one-hot encoding
for col in X.select_dtypes(include=['object']).columns:
    X = pd.get_dummies(X, columns=[col], prefix=[col], drop_first=True)

y = data['Credit_Score']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model = RandomForestClassifier(n_estimators=10, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=10, random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)

# %%
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.7154759425119767

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

# %%
print(f'conf_matrix: {conf_matrix}')
# Out:
# conf_matrix: [[ 443    5  308]
#  [  43 1072  396]
#  [ 188  426 1920]]

# %%
class_report = classification_report(y_test, y_pred)

# %%
print(f'class_report: {class_report}')
# Out:
# class_report:               precision    recall  f1-score   support
#
#         Good       0.66      0.59      0.62       756
#         Poor       0.71      0.71      0.71      1511
#     Standard       0.73      0.76      0.74      2534
#
#     accuracy                           0.72      4801
#    macro avg       0.70      0.68      0.69      4801
# weighted avg       0.71      0.72      0.71      4801
